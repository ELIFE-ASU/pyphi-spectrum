# %% [markdown]
# ## Notebook to make a four-panel figure with each of the 4 solutions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_style('darkgrid')
# %matplotlib inline


## Initialize fig, ax objects
fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, figsize=(16,9))


## Get SMALLEST in upper left
smallest_gomez = pd.read_csv("SMALLEST/results/smallest_spectrum_gomez_2021.csv",header=None,squeeze=True)
smallest_hoel = pd.read_csv("SMALLEST/results/smallest_spectrum_hoel_2016.csv",header=None,squeeze=True)
smallest_farnsworth_full = pd.read_csv("SMALLEST/results/smallest_spectrum_farnsworth_full.csv",header=None,squeeze=True)
smallest_farnsworth_reduced = pd.read_csv("SMALLEST/results/smallest_spectrum_farnsworth_reduced.csv",header=None,squeeze=True)
smallest_oizumi = pd.read_csv("SMALLEST/results/smallest_spectrum_oizumi_2014.csv",header=None,squeeze=True)
smallest_marshall = pd.read_csv("SMALLEST/results/smallest_spectrum_marshall_2017.csv",header=None,squeeze=True)
smallest_and_or = pd.read_csv("SMALLEST/results/smallest_spectrum_and_or.csv",header=None,squeeze=True)
smallest_photodiode = pd.read_csv("SMALLEST/results/smallest_spectrum_photodiode.csv",header=None,squeeze=True)
smallest_tononi = pd.read_csv("SMALLEST/results/smallest_spectrum_tononi_2016.csv",header=None,squeeze=True)
smallest_hanson_101 = pd.read_csv("SMALLEST/results/smallest_spectrum_hanson_101.csv",header=None,squeeze=True)

SMALLEST_data_dict = {'AND+OR':[smallest_and_or,0.090278], 'Farnsworth 2021 (Full)':[smallest_farnsworth_full,0.3125], 
             'Farnsworth 2021 (Reduced)':[smallest_farnsworth_reduced,0.4375], 'Gomez et al. 2020':[smallest_gomez,0.215278], 
             'Photodiode':[smallest_photodiode,1.0000], 'Hanson and Walker 2020':[smallest_hanson_101,1.625], 
             'Marshall et al. 2017':[smallest_marshall,0.090278], 'Hoel et al. 2016':[smallest_hoel, 0.11389], 
             'Tononi et al. 2016':[smallest_tononi, 0.659722],'Oizumi et al. 2014':[smallest_oizumi,1.916665]}


## Plot SMALLEST
index = 0
for key in SMALLEST_data_dict.keys():
    size_of_Phi = len(SMALLEST_data_dict[key][0]) ## number of degenerate Phi MIP values
    ax[0,0].scatter([index]*size_of_Phi,SMALLEST_data_dict[key][0],alpha=0.5,s=50,label=None)
#     if index == 0:
#         ax[0,0].scatter([index],SMALLEST_data_dict[key][1],marker='x',color='black',label='Published Value') # with label
#     else:
#         ax[0,0].scatter([index],SMALLEST_data_dict[key][1],marker='x',color='black')   # no label
        
#     ax[0,0].annotate(r'|$\Phi^{MIP}$| = '+str(size_of_Phi),(index-0.35,np.max(SMALLEST_data_dict[key][0])+0.055))
    index=index+1
    
    
## Get BIGGEST purview in upper right
biggest_gomez = pd.read_csv("BIGGEST/results/biggest_spectrum_gomez_2021.csv",header=None,squeeze=True)
biggest_hoel = pd.read_csv("BIGGEST/results/biggest_spectrum_hoel_2016.csv",header=None,squeeze=True)
biggest_farnsworth_full = pd.read_csv("BIGGEST/results/biggest_spectrum_farnsworth_full.csv",header=None,squeeze=True)
biggest_farnsworth_reduced = pd.read_csv("BIGGEST/results/biggest_spectrum_farnsworth_reduced.csv",header=None,squeeze=True)
biggest_oizumi = pd.read_csv("BIGGEST/results/biggest_spectrum_oizumi_2014.csv",header=None,squeeze=True)
biggest_marshall = pd.read_csv("BIGGEST/results/biggest_spectrum_marshall_2017.csv",header=None,squeeze=True)
biggest_and_or = pd.read_csv("BIGGEST/results/biggest_spectrum_and_or.csv",header=None,squeeze=True)
biggest_photodiode = pd.read_csv("BIGGEST/results/biggest_spectrum_photodiode.csv",header=None,squeeze=True)
biggest_tononi = pd.read_csv("BIGGEST/results/biggest_spectrum_tononi_2016.csv",header=None,squeeze=True)
biggest_hanson_101 = pd.read_csv("BIGGEST/results/biggest_spectrum_hanson_101.csv",header=None,squeeze=True)


BIGGEST_data_dict = {'AND+OR':[biggest_and_or,0.090278], 'Farnsworth 2021 (Full)':[biggest_farnsworth_full,0.3125], 
             'Farnsworth 2021 (Reduced)':[biggest_farnsworth_reduced,0.4375], 'Gomez et al. 2020':[biggest_gomez,0.215278], 
             'Photodiode':[biggest_photodiode,1.0000], 'Hanson and Walker 2020':[biggest_hanson_101,1.625], 
             'Marshall et al. 2017':[biggest_marshall,0.090278], 'Hoel et al. 2016':[biggest_hoel, 0.11389], 
             'Tononi et al. 2016':[biggest_tononi, 0.659722],'Oizumi et al. 2014':[biggest_oizumi,1.916665]}

## Plot BIGGEST
index = 0
for key in BIGGEST_data_dict.keys():
    size_of_Phi = len(BIGGEST_data_dict[key][0]) ## number of degenerate Phi MIP values
    ax[0,1].scatter([index]*size_of_Phi,BIGGEST_data_dict[key][0],alpha=0.5,s=50,label=None)
#     if index == 0:
#         ax[0,1].scatter([index],BIGGEST_data_dict[key][1],marker='x',color='black',label='Published Value') # with label
#     else:
#         ax[0,1].scatter([index],BIGGEST_data_dict[key][1],marker='x',color='black')   # no label
        
#     ax[0,1].annotate(r'|$\Phi^{MIP}$| = '+str(size_of_Phi),(index-0.35,np.max(BIGGEST_data_dict[key][0])+0.075))
    index=index+1
    
    
#### Plot MOON in the lower left
moon_gomez = pd.read_csv("MOON/results/moon_spectrum_gomez_2021.csv",header=None,squeeze=True)
moon_hoel = pd.read_csv("MOON/results/moon_spectrum_hoel_2016.csv",header=None,squeeze=True)
moon_farnsworth_full = pd.read_csv("MOON/results/moon_spectrum_farnsworth_full.csv",header=None,squeeze=True)
moon_farnsworth_reduced = pd.read_csv("MOON/results/moon_spectrum_farnsworth_reduced.csv",header=None,squeeze=True)
moon_oizumi = pd.read_csv("MOON/results/moon_spectrum_oizumi_2014.csv",header=None,squeeze=True)
moon_marshall = pd.read_csv("MOON/results/moon_spectrum_marshall_2017.csv",header=None,squeeze=True)
moon_and_or = pd.read_csv("MOON/results/moon_spectrum_and_or.csv",header=None,squeeze=True)
moon_photodiode = pd.read_csv("MOON/results/moon_spectrum_photodiode.csv",header=None,squeeze=True)
moon_tononi = pd.read_csv("MOON/results/moon_spectrum_tononi_2016.csv",header=None,squeeze=True)
moon_hanson_101 = pd.read_csv("MOON/results/moon_spectrum_hanson_101.csv",header=None,squeeze=True)


MOON_data_dict = {'AND+OR':[moon_and_or,0.090278], 'Farnsworth 2021 (Full)':[moon_farnsworth_full,0.3125], 
             'Farnsworth 2021 (Reduced)':[moon_farnsworth_reduced,0.4375], 'Gomez et al. 2020':[moon_gomez,0.215278], 
             'Photodiode':[moon_photodiode,1.0000], 'Hanson and Walker 2020':[moon_hanson_101,1.625], 
             'Marshall et al. 2017':[moon_marshall,0.090278], 'Hoel et al. 2016':[moon_hoel, 0.11389], 
             'Tononi et al. 2016':[moon_tononi, 0.659722],'Oizumi et al. 2014':[moon_oizumi,1.916665]}

index = 0
for key in MOON_data_dict.keys():
    size_of_Phi = len(MOON_data_dict[key][0]) ## number of degenerate Phi MIP values
    ax[1,0].scatter([index]*size_of_Phi,MOON_data_dict[key][0],alpha=0.5,s=50,label=None)
#     if index == 0:
#         ax[1,0].scatter([index],MOON_data_dict[key][1],marker='x',color='black',label='Published Value') # with label
#     else:
#         ax[1,0].scatter([index],MOON_data_dict[key][1],marker='x',color='black')   # no label
        
#     ax[1,0].annotate(r'|$\Phi^{MIP}$| = '+str(size_of_Phi),(index-0.35,np.max(MOON_data_dict[key][0])+0.075))
    index=index+1
    

## Get KO17 in lower right
KO17_gomez = pd.read_csv("KO17/results/phi_spectrum_gomez_2021.csv",header=None,squeeze=True)
KO17_hoel = pd.read_csv("KO17/results/phi_spectrum_hoel_2016.csv",header=None,squeeze=True)
KO17_farnsworth_full = pd.read_csv("KO17/results/phi_spectrum_farnsworth_full.csv",header=None,squeeze=True)
KO17_farnsworth_reduced = pd.read_csv("KO17/results/phi_spectrum_farnsworth_reduced.csv",header=None,squeeze=True)
KO17_oizumi = pd.read_csv("KO17/results/phi_spectrum_oizumi_2014.csv",header=None,squeeze=True)
KO17_marshall = pd.read_csv("KO17/results/phi_spectrum_marshall_2017.csv",header=None,squeeze=True)
KO17_and_or = pd.read_csv("KO17/results/phi_spectrum_and_or.csv",header=None,squeeze=True)
KO17_photodiode = pd.read_csv("KO17/results/phi_spectrum_photodiode.csv",header=None,squeeze=True)
KO17_tononi = pd.read_csv("KO17/results/phi_spectrum_tononi_2016.csv",header=None,squeeze=True)
KO17_hanson_101 = pd.read_csv("KO17/results/phi_spectrum_hanson_101.csv",header=None,squeeze=True)


KO_17_dict = {'AND+OR':[KO17_and_or,0.090278], 'Farnsworth 2021 (Full)':[KO17_farnsworth_full,0.3125], 
             'Farnsworth 2021 (Reduced)':[KO17_farnsworth_reduced,0.4375], 'Gomez et al. 2020':[KO17_gomez,0.215278], 
             'Photodiode':[KO17_photodiode,1.0000], 'Hanson and Walker 2020':[KO17_hanson_101,1.625], 'Marshall et al. 2017':[KO17_marshall,0.090278], 
             'Hoel et al. 2016':[KO17_hoel, 0.11389], 'Tononi et al. 2016':[KO17_tononi, 0.659722],
             'Oizumi et al. 2014':[KO17_oizumi,1.916665]}


## Plot KO17
index = 0
for key in KO_17_dict.keys():
    size_of_Phi = len(KO_17_dict[key][0]) ## number of degenerate Phi MIP values
    ax[1,1].scatter([index]*size_of_Phi,KO_17_dict[key][0],alpha=0.5,s=50,label=key)
#     if index == len(KO_17_dict)-1:
#         ax[1,1].scatter([index],KO_17_dict[key][1],marker='x',color='black',label='Published Value') # with label
#     else:
#         ax[1,1].scatter([index],KO_17_dict[key][1],marker='x',color='black')   # no label
        
#     ax[1,1].annotate(r'|$\Phi^{MIP}$| = '+str(size_of_Phi),(index-0.35,np.max(KO_17_dict[key][0])+0.075))
    index=index+1


    
ax[0,0].set_title('SMALLEST',size=16)
ax[0,1].set_title('BIGGEST',size=16)
ax[1,0].set_title('MOON',size=16)
ax[1,1].set_title('KO17',size=16)

# ax[1,0].set_xticks(np.arange(len(KO_17_dict)),KO_17_dict.keys())
# ax[1,1].set_xticks(np.arange(len(KO_17_dict)),KO_17_dict.keys())

plt.setp(ax, xticks=np.arange(len(KO_17_dict)), xticklabels=KO_17_dict.keys())
ax[1,0].tick_params(axis="x", rotation=90, labelsize=16)
ax[1,1].tick_params(axis="x", rotation=90, labelsize=16)
ax[0,1].set_ylabel(None)
ax[1,1].set_ylabel(None)
ax[0,0].set_ylabel(r'$\Phi^{MIP}$ Value(s)',size=16)
ax[1,0].set_ylabel(r'$\Phi^{MIP}$ Value(s)',size=16)

               
#                .set_title('v = 1',fontweight="bold", size=20) # Title



# plt.legend(ncol=2,bbox_to_anchor=[0,2.5])
plt.tight_layout()
plt.savefig('ALL_SOLUTIONS.pdf')
plt.show()

    
## Clean Up
# ax[1,1].title(r'KO17',fontsize=14)
# ax[1,1].ylabel(r'$\Phi^{MIP}$ Value(s)',fontsize=14)
# ax[1,1].xticks(np.arange(len(data_dict)),KO_17_dict.keys(),rotation=90,fontsize=14)
# ax[1,1].legend(loc='upper left',fontsize=14)
# ax[1,1].ylim((-0.1,2.5))
# plt.tight_layout()
# plt.savefig('Phi_MIP_Corpus_KO17.pdf')
# plt.show()
